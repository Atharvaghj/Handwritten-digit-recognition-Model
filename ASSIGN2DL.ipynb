# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import random

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
x_train=x_train/255.0
x_test=x_test/255.0

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(256,activation='relu'),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer="sgd",loss="sparse_categorical_crossentropy",metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5744 - accuracy: 0.8521 - val_loss: 0.2920 - val_accuracy: 0.9199
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2752 - accuracy: 0.9216 - val_loss: 0.2326 - val_accuracy: 0.9343
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2244 - accuracy: 0.9355 - val_loss: 0.1967 - val_accuracy: 0.9445
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1912 - accuracy: 0.9449 - val_loss: 0.1754 - val_accuracy: 0.9494
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1679 - accuracy: 0.9511 - val_loss: 0.1562 - val_accuracy: 0.9552
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1494 - accuracy: 0.9575 - val_loss: 0.1414 - val_accuracy: 0.9586
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1343 - accuracy: 0.9620 - val_loss: 0.1310 - val_accuracy: 0.9609
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1218 - accuracy: 0.9657 - val_loss: 0.1249 - val_accuracy: 0.9624
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1111 - accuracy: 0.9686 - val_loss: 0.1135 - val_accuracy: 0.9659
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1017 - accuracy: 0.9711 - val_loss: 0.1074 - val_accuracy: 0.9681

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print("Loss=",test_loss)
print("Accuracy=%.3f" %test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1073 - accuracy: 0.9685
# Loss= 0.10728699713945389
# Accuracy=0.969

# %%
n=random.randint(0,9999)
plt.imshow(x_train[n])
plt.show()

predicted_value=model.predict(x_test)
plt.imshow(x_test[n])
plt.show()

print(predicted_value[n])
# Out:
# 313/313 [==============================] - 1s 3ms/step
# [1.5664826e-08 9.8923928e-01 1.5202446e-04 1.1528773e-03 8.2753372e-04
#  1.0811210e-04 2.5380359e-05 7.1087838e-05 8.2786400e-03 1.4492516e-04]

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Plotting The Training Accuracy :-
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
n =2
plt.imshow(x_test[n])
predicted_value = model.predict(x_test)
print("Actual Number: ",np.argmax(y_test[n]))
print("Predicted Number: ", np.argmax(predicted_value[n]))
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Actual Number:  0
# Predicted Number:  1
